# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np

# %% [markdown]
# ## This section uses the multiworld environment API
# https://github.com/vitchyr/multiworld/

# %%
from crafting_env.multiworld_crafting_env import MultiworldCraftingEnv

# %%
env = MultiworldCraftingEnv(pretty_renderable=True)
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# asset_path /home/coline/arxiv_cpv/craftingworld/crafting_env/assets/*.png
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.

# %%
obs = env.reset()

# %%
a = np.random.randint(6)
print(a)
obs,r,d,info  = env.step(a)
obs = obs['observation']
plt.imshow(obs.reshape(33,30,3)[:,:,::-1])
# Out:
# 5

# %%
obs = env.pretty_render()
plt.imshow(obs.reshape(33*10,30*10,3)[:,:,::-1])

# %% [markdown]
# ## This section uses the GymEnv API

# %%
from crafting_env.gym_crafting_env import GymCraftingEnv

# %%
env = CraftingGymEnv(res=3)
# Out:
# WARN: gym.spaces.Box autodetected dtype as <class 'numpy.float32'>. Please provide explicit dtype.

# %%
obs = env.reset()

# %%
a = np.random.randint(6)
print(a)
obs,r,d,info  = env.step(a)
plt.imshow(obs.reshape(33,30,3)[:,:,::-1])
# Out:
# 1
